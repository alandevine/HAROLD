# %%
from baselines.common import plot_util as pu
results = pu.load_results('/home/fuentes/programming/harold/code/logs')
# Out:
# /home/fuentes/programming/baselines/baselines/bench/monitor.py:162: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(len(results)):
    r = results[i]
    print(f"Harold_HER_v{i+1}")
    plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
# Out:
# Harold_HER_v1
# Harold_HER_v2
# Harold_HER_v3
# Harold_HER_v4

# %%
for i in range(len(results)):
    r = results[i]
    print(f"Harold_HER_v{i+1}")
    plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=30))
# Out:
# Harold_HER_v1
# Harold_HER_v2
# Harold_HER_v3
# Harold_HER_v4

# %%
pu.plot_results(results, average_group=True)
# Out:
# (<Figure size 432x1728 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9e7af3f860>],
# ...
#        dtype=object))

# %%
pu.plot_results(results, average_group=True, shaded_std=True, split_fn=lambda _: '')
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9e7b06a198>]],
#        dtype=object))
